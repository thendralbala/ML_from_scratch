# %% [markdown]
# <a href="https://colab.research.google.com/github/thendralbala/ML_from_scratch/blob/main/8_Estimating_Traffic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn import preprocessing
from sklearn.svm import SVR

# %%
def load_data(input_file):
  X = []
  with open(input_file,'r') as f:
    for line in f.readlines():
      data = line[:-1].split(',')
      X.append(data)

  X = np.array(X)

  return X

X = load_data('traffic_data.txt')

# %%
print(X)
# Out:
# [['Tuesday' '00:00' 'San Francisco' 'no' '3']
#  ['Tuesday' '00:05' 'San Francisco' 'no' '8']
#  ['Tuesday' '00:10' 'San Francisco' 'no' '10']
#  ...
#  ['Thursday' '23:45' 'Arizona' 'no' '11']
#  ['Thursday' '23:50' 'Arizona' 'no' '14']
#  ['Thursday' '23:55' 'Arizona' 'no' '17']]

# %%
label_encoder = []
X_encoded = np.empty(X.shape)
for i,item in enumerate(X[0]):
  if item.isdigit():
    X_encoded[:,i] = X[:,i]
  else:
    label_encoder.append(preprocessing.LabelEncoder())
    X_encoded[:,i] = label_encoder[-1].fit_transform(X[:,i])
X = X_encoded[:,:-1].astype(int)
y = X_encoded[:,-1].astype(int)

# %%
params = {'kernel':'rbf', 'C':10.0, 'epsilon': 0.2}
regressor = SVR(**params)
regressor.fit(X,y)
# Out:
# SVR(C=10.0, epsilon=0.2)

# %%
#Cross Validation
import sklearn.metrics as sm

y_pred = regressor.predict(X)

print(f"Mean absolute error = {round(sm.mean_absolute_error(y,y_pred),2)}")
# Out:
# Mean absolute error = 7.28
